# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.preprocessing import StandardScaler
x = np.array([1, 2, 4, 3, 5])
y = np.array([1, 3, 4, 3, 7])
print(x.shape)
print(y.shape)
print(x)
print(y)
x = x.reshape(-1, 1)
print(x.shape)
print(x)
model = LinearRegression()
model.fit(x, y)
print("Prediction for x=8:", model.predict([[8]]))
y_pred = model.predict(x)

plt.scatter(x, y, color='r', marker='o')
plt.plot(x, y_pred, color='b', linewidth=2)
plt.xlabel('x')
plt.ylabel('y')
plt.title("Linear Regression")
plt.show()
print("Linear Regression Coeff:", model.coef_)
print("Linear Regression Intercept:", model.intercept_)
scaler = StandardScaler()
x_stand = scaler.fit_transform(x.astype(float))
sgdr = SGDRegressor(penalty='l2', alpha=0.15, max_iter=1000)
sgdr.fit(x_stand, y)
x_input = np.array([[10]])
x_input_scaled = scaler.transform(x_input)
print("SGD Prediction for x=10:", sgdr.predict(x_input_scaled))
y_pred2 = sgdr.predict(x_stand)
plt.scatter(x_stand, y, color='g', marker='o')
plt.plot(x_stand, y_pred2, color='b', linewidth=2)
plt.xlabel('x_normalized')
plt.ylabel('y')
plt.title("SGD Regression")
plt.show()
print("SGD Coeff:", sgdr.coef_)
print("SGD Intercept:", sgdr.intercept_)
# Out:
# (5,)
# (5,)
# [1 2 4 3 5]
# [1 3 4 3 7]
# (5, 1)
# [[1]
#  [2]
#  [4]
#  [3]
#  [5]]
# Prediction for x=8: [10.1]
# Linear Regression Coeff: [1.3]
# Linear Regression Intercept: -0.30000000000000027
# SGD Prediction for x=10: [10.99564928]
# SGD Coeff: [1.53743152]
# SGD Intercept: [3.3857515]
